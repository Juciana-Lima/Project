# %%
import pandas as pd
import numpy as np

# %%
##Leitura do dataset docentes/turma
df_acidentes=pd.read_csv("C:/Treino_R/Transito/Acidentes_DadosAbertos_20241212.csv", encoding="Windows-1252",sep=';')
# Out:
# C:\Users\juciana.lima\AppData\Local\anaconda3\envs\rstudio\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Visualização do df
display(df_acidentes)
# Out:
#          num_acidente   chv_localidade data_acidente uf_acidente  \
# 0              524877  AC1200401201801    2018-01-26          AC
# 1             2304421  AC1200401201801    2018-01-21          AC
# 2             2924496  AC1200708201801    2018-01-14          AC
# 3             2844648  AC1200401201801    2018-01-18          AC
# 4             2003099  AC1200401201801    2018-01-26          AC
# ...               ...              ...           ...         ...
# 6496103       4383720  TO1702109202408    2024-08-22          TO
# 6496104        915170  TO1716109202408    2024-08-22          TO
# 6496105        636740  TO1721000202408    2024-08-20          TO
# 6496106        290028  TO1718204202408    2024-08-18          TO
# 6496107       1919430  TO1702554202408    2024-08-16          TO
#
#          ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge  \
# 0                2018             1             12018      1200401
# ...

# %%
df_acidentes.shape
# Out:
# (6496108, 35)

# %%
#Visualização dos 5 primeiros
df_acidentes.head(5)
# Out:
#    num_acidente   chv_localidade data_acidente uf_acidente  ano_acidente  \
# 0        524877  AC1200401201801    2018-01-26          AC          2018
# 1       2304421  AC1200401201801    2018-01-21          AC          2018
# 2       2924496  AC1200708201801    2018-01-14          AC          2018
# 3       2844648  AC1200401201801    2018-01-18          AC          2018
# 4       2003099  AC1200401201801    2018-01-26          AC          2018
#
#    mes_acidente  mes_ano_acidente  codigo_ibge    dia_semana fase_dia  ...  \
# 0             1             12018      1200401   SEXTA-FEIRA    MANHA  ...
# 1             1             12018      1200401       DOMINGO    MANHA  ...
# 2             1             12018      1200708       DOMINGO    MANHA  ...
# 3             1             12018      1200401  QUINTA-FEIRA    TARDE  ...
# 4             1             12018      1200401   SEXTA-FEIRA    NOITE  ...
#
#   lim_velocidade       tp_pista  ind_guardrail  ind_cantcentral  \
# ...

# %%
#Visualização dos 5 útlimos
df_acidentes.tail(5)
# Out:
#          num_acidente   chv_localidade data_acidente uf_acidente  \
# 6496103       4383720  TO1702109202408    2024-08-22          TO
# 6496104        915170  TO1716109202408    2024-08-22          TO
# 6496105        636740  TO1721000202408    2024-08-20          TO
# 6496106        290028  TO1718204202408    2024-08-18          TO
# 6496107       1919430  TO1702554202408    2024-08-16          TO
#
#          ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge  \
# 6496103          2024             8             82024      1702109
# 6496104          2024             8             82024      1716109
# 6496105          2024             8             82024      1721000
# 6496106          2024             8             82024      1718204
# 6496107          2024             8             82024      1702554
#
#            dia_semana fase_dia  ... lim_velocidade       tp_pista  \
# 6496103  QUINTA-FEIRA    TARDE  ...  NAO INFORMADO  NAO INFORMADO
# ...

# %%
#Visualização dos 5 últimos
df_acidentes.head(5)
# Out:
#    num_acidente   chv_localidade data_acidente uf_acidente  ano_acidente  \
# 0        524877  AC1200401201801    2018-01-26          AC          2018
# 1       2304421  AC1200401201801    2018-01-21          AC          2018
# 2       2924496  AC1200708201801    2018-01-14          AC          2018
# 3       2844648  AC1200401201801    2018-01-18          AC          2018
# 4       2003099  AC1200401201801    2018-01-26          AC          2018
#
#    mes_acidente  mes_ano_acidente  codigo_ibge    dia_semana fase_dia  ...  \
# 0             1             12018      1200401   SEXTA-FEIRA    MANHA  ...
# 1             1             12018      1200401       DOMINGO    MANHA  ...
# 2             1             12018      1200708       DOMINGO    MANHA  ...
# 3             1             12018      1200401  QUINTA-FEIRA    TARDE  ...
# 4             1             12018      1200401   SEXTA-FEIRA    NOITE  ...
#
#   lim_velocidade       tp_pista  ind_guardrail  ind_cantcentral  \
# ...

# %%
#Nomes das colunas
df_acidentes.columns
# Out:
# Index(['num_acidente', 'chv_localidade', 'data_acidente', 'uf_acidente',
#        'ano_acidente', 'mes_acidente', 'mes_ano_acidente', 'codigo_ibge',
#        'dia_semana', 'fase_dia', 'tp_acidente', 'cond_meteorologica',
#        'end_acidente', 'num_end_acidente', 'cep_acidente', 'bairro_acidente',
#        'km_via_acidente', 'latitude_acidente', 'longitude_acidente',
#        'hora_acidente', 'tp_rodovia', 'cond_pista', 'tp_cruzamento',
#        'tp_pavimento', 'tp_curva', 'lim_velocidade', 'tp_pista',
#        'ind_guardrail', 'ind_cantcentral', 'ind_acostamento', 'qtde_acidente',
#        'qtde_acid_com_obitos', 'qtde_envolvidos', 'qtde_feridosilesos',
#        'qtde_obitos'],
#       dtype='object')

# %%
df_acidentes.sort_index()
# Out:
#          num_acidente   chv_localidade data_acidente uf_acidente  \
# 0              524877  AC1200401201801    2018-01-26          AC
# 1             2304421  AC1200401201801    2018-01-21          AC
# 2             2924496  AC1200708201801    2018-01-14          AC
# 3             2844648  AC1200401201801    2018-01-18          AC
# 4             2003099  AC1200401201801    2018-01-26          AC
# ...               ...              ...           ...         ...
# 6496103       4383720  TO1702109202408    2024-08-22          TO
# 6496104        915170  TO1716109202408    2024-08-22          TO
# 6496105        636740  TO1721000202408    2024-08-20          TO
# 6496106        290028  TO1718204202408    2024-08-18          TO
# 6496107       1919430  TO1702554202408    2024-08-16          TO
#
#          ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge  \
# 0                2018             1             12018      1200401
# ...

# %%
df_acidentes['qtde_acid_com_obitos'].describe()
# Out:
# count    6.496108e+06
# mean     2.071456e-02
# std      1.424271e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: qtde_acid_com_obitos, dtype: float64

# %%
###Ordenar por ano
df_acidentes.sort_values(by="dia_semana")
# Out:
#          num_acidente   chv_localidade data_acidente uf_acidente  \
# 1102196       3555598  GO5221403202111    2021-11-07          GO
# 718021        1765011  ES3204005202305    2023-05-14          ES
# 718022        3603396  ES3205002202305    2023-05-14          ES
# 718023        4440692  ES3202801202305    2023-05-14          ES
# 718024        1975557  ES3201506202305    2023-05-14          ES
# ...               ...              ...           ...         ...
# 2775222       2227862  MG3129806202306    2023-06-13          MG
# 2775223       6125580  MG3106200202306    2023-06-27          MG
# 2775225       1208516  MG3106200202306    2023-06-27          MG
# 2770639       2354450  MG3154309202306    2023-06-13          MG
# 3248053       6191171  MS5002704202407    2024-07-30          MS
#
#          ano_acidente  mes_acidente  mes_ano_acidente  codigo_ibge  \
# 1102196          2021            11            112021      5221403
# ...

# %%
df_acidentes["fase_dia"].value_counts(ascending=False)
# Out:
# TARDE            2427490
# MANHA            1834462
# NOITE            1747662
# MADRUGADA         430999
# NAO INFORMADO      51801
# DESCONHECIDO        3694
# Name: fase_dia, dtype: int64

# %%
df_acidentes["ano_acidente"].value_counts(ascending=False)
# Out:
# 2023    1097447
# 2022    1066758
# 2021    1012953
# 2019    1007735
# 2020     912312
# 2018     721915
# 2024     676988
# Name: ano_acidente, dtype: int64

# %%
df_acidentes["uf_acidente"].value_counts(ascending=False)
# Out:
# MG    1736261
# SP    1081292
# SC     936983
# PR     614827
# GO     599785
# ES     279331
# DF     258311
# PA     144479
# MS     128677
# RJ     114370
# CE      90825
# BA      90760
# RO      85940
# PE      69654
# PI      68411
# TO      29601
# MT      28065
# RN      28059
# AC      22115
# MA      17552
# RR      16234
# PB      14587
# AL      11986
# AP       7437
# RS       7310
# AM       7080
# SE       6176
# Name: uf_acidente, dtype: int64

# %%
df_acidentes["dia_semana"].value_counts(ascending=False)
# Out:
# SEXTA-FEIRA      1058129
# SABADO            970868
# SEGUNDA-FEIRA     942374
# QUINTA-FEIRA      928174
# QUARTA-FEIRA      918264
# TERCA-FEIRA       903049
# DOMINGO           775250
# Name: dia_semana, dtype: int64

# %%
df_acidentes.iloc[5:10]

# %%
df_acidentes.dtypes

# %%
df_acidentes.sort_values(by="ano_acidente",ascending=False)

# %%
df_acidentes.groupby(["ano_acidente"]).agg("max","min")

# %%
df_acidentes["fase_dia"]=(df_acidentes["mes_acidente"]).astype(int)

# %%
pd.isna(df_acidentes).value_counts().sum()

# %%
df_acidentes.isnull().sum()

# %%
df_acidentes.loc[[1000],:]

# %%
df_acidentes.groupby("ano_acidente")[["qtde_acid_com_obitos"]].sum().asceding=True

# %%
df_acidentes.info

# %%
df_acidentes["mes_acidente"]=(df_acidentes["mes_acidente"]).astype(int)

# %%
df_acidentes["mes_acidente"].value_counts()

# %%
df_acidentes["mes_acidente"].value_counts().tail(5)

# %%
df_acidentes["mes_acidente"].value_counts(ascending=False)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df_acidentes["qtde_envolvidos"],df_acidentes["qtde_obitos"], color='red')
plt.show()

# %%
plt.bar(df_acidentes['mes_acidente'],df_acidentes['qtde_obitos'],color='blue')
plt.xlabel('mês do ano')
plt.ylabel('quantidade de obitos')
plt.title('Mês do ano versus obitos)
plt.show()
